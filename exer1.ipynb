# %%
import numpy as np

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\23adsb66\Downloads\heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
# Prep features and target
X = df.drop(columns=['output'])
y = df['output']

# %%
print(X)
print(X.shape)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall
# 0      0      1
# 1      0      2
# 2      0      2
# 3      0      2
# 4      0      2
# ..   ...    ...
# 298    0      3
# 299    0      3
# 300    2      3
# 301    1      3
# 302    1      2
#
# [303 rows x 13 columns]
# (303, 13)

# %%
print(y)
print(y.shape)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 303, dtype: int64
# (303,)

# %%
unique_values = np.unique(y)
counts = np.zeros_like(unique_values)

for i, value in enumerate(unique_values):
  counts[i] = np.count_nonzero(y == value)

for i, value in enumerate(unique_values):
  print(f"Class label: {value}, Count: {counts[i]}")
# Out:
# Class label: 0, Count: 138
# Class label: 1, Count: 165

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.2, random_state=0)

# %%
print(X_train)
print(X_train.shape)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 74    43    0   2     122   213    0        1       165     0      0.2    1
# 153   66    0   2     146   278    0        0       152     0      0.0    1
# 64    58    1   2     140   211    1        0       165     0      0.0    2
# 296   63    0   0     124   197    0        1       136     1      0.0    1
# 287   57    1   1     154   232    0        0       164     0      0.0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 251   43    1   0     132   247    1        0       143     1      0.1    1
# 192   54    1   0     120   188    0        1       113     0      1.4    1
# 117   56    1   3     120   193    0        0       162     0      1.9    1
# 47    47    1   2     138   257    0        0       156     0      0.0    2
# 172   58    1   1     120   284    0        0       160     0      1.8    1
#
#      caa  thall
# 74     0      2
# 153    1      2
# 64     0      2
# 296    0      2
# 287    1      2
# ..   ...    ...
# 251    4      3
# 192    1      3
# 117    0      3
# 47     0      2
# 172    0      2
#
# [242 rows x 13 columns]
# (242, 13)

# %%
print(X_test)
print(X_test.shape)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 225   70    1   0     145   174    0        1       125     1      2.6    0
# 152   64    1   3     170   227    0        0       155     0      0.6    1
# 228   59    1   3     170   288    0        0       159     0      0.2    1
# 201   60    1   0     125   258    0        0       141     1      2.8    1
# 52    62    1   2     130   231    0        1       146     0      1.8    1
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 146   44    0   2     118   242    0        1       149     0      0.3    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
# 26    59    1   2     150   212    1        1       157     0      1.6    2
# 108   50    0   1     120   244    0        1       162     0      1.1    2
# 89    58    0   0     100   248    0        0       122     0      1.0    1
#
#      caa  thall
# 225    0      3
# 152    0      3
# 228    0      3
# 201    1      3
# 52     3      3
# ..   ...    ...
# 146    1      2
# 302    1      2
# 26     0      2
# 108    0      2
# 89     0      2
#
# [61 rows x 13 columns]
# (61, 13)

# %%
print(y_train)
print(y_train.shape)
# Out:
# 74     1
# 153    1
# 64     1
# 296    0
# 287    0
#       ..
# 251    0
# 192    0
# 117    1
# 47     1
# 172    0
# Name: output, Length: 242, dtype: int64
# (242,)

# %%
print(y_test)
print(y_test.shape)
# Out:
# 225    0
# 152    1
# 228    0
# 201    0
# 52     1
#       ..
# 146    1
# 302    0
# 26     1
# 108    1
# 89     1
# Name: output, Length: 61, dtype: int64
# (61,)

# %%
# prompt: print count of o and 1 in test data

unique_values = np.unique(y_test)
counts = np.zeros_like(unique_values)

for i, value in enumerate(unique_values):
  counts[i] = np.count_nonzero(y_test == value)

for i, value in enumerate(unique_values):
  print(f"Class label: {value}, Count: {counts[i]}")
# Out:
# Class label: 0, Count: 27
# Class label: 1, Count: 34

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0
  1.        ,  0.        ,
#          1.        ,  0.        ,  0.66666667],
#        [ 0.25      ,  1.        ,  0.33333333,  0.41836735,  0.16628176,
#          0.        ,  0.5       ,  0.46564885,  0.        ,  0.        ,
#          0.5       ,  0.        ,  0.33333333],
#        [ 0.20833333,  0.        ,  0.66666667,  0.        ,  0.15704388,
#          0.        ,  0.5       ,  0.82442748,  0.        ,  0.        ,
#          1.        ,  0.        ,  0.66666667],
#        [ 0.125     ,  1.        ,  0.        ,  0.26530612,  0.15473441,
#          0.        ,  0.5       ,  0.45038168,  1.        ,  0.25806452,
#          0.5       ,  0.        ,  1.        ],
#        [ 0.3125    ,  0.        ,  0.66666667,  0.24489796,  0.25635104,
#          0.        ,  0.5       ,  0.59541985,  0.        ,  0.0483871 ,
#          0.5       ,  0.25      ,  0.66666667],
#        [ 0.58333333,  0.        ,  0.33333333,  0.36734694,  0.24249423,
#          0.        ,  0.        ,  0.78625954,  0.        ,  0.        ,
#          0.5       ,  0.25      ,  0.66666667],
#        [ 0.625     ,  1.        ,  0.66666667,  0.57142857,  0.18706697,
#          1.        ,  0.5       ,  0.65648855,  0.        ,  0.25806452,
#          1.        ,  0.        ,  0.66666667],
#        [ 0.4375    ,  0.        ,  0.33333333,  0.26530612,  0.26096998,
#          0.        ,  0.5       ,  0.69465649,  0.        ,  0.17741935,
#          1.        ,  0.        ,  0.66666667],
#        [ 0.60416667,  0.        ,  0.        ,  0.06122449,  0.27020785,
#          0.        ,  0.        ,  0.38931298,  0.        ,  0.16129032,
#          0.5       ,  0.        ,  0.66666667]])

# %%
import sklearn
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import precision_recall_curve,roc_curve, auc, roc_auc_score
from sklearn.metrics import balanced_accuracy_score

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(X_train, y_train.to_numpy())
# Out:
# GaussianNB()

# %%
# Predict on test set using fitted model
preds = nb_model.predict(X_test)

# %%
#testing accuracy
accuracy_score(y_test, preds)
# Out:
# 0.8524590163934426

# %%
#print confusion matrix
classes = ["Normal","AbNormal"]
cm = confusion_matrix(y_test,preds)

print('Confusion Matrix')
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=classes)
fig, ax = plt.subplots(figsize=(5,5))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Confusion Matrix
# [[21  6]
#  [ 3 31]]

# %%
Accuracy = metrics.accuracy_score(y_test, preds)
print('Accuracy:', Accuracy*100)

Precision = metrics.precision_score(y_test, preds)
print('Precision:', Precision*100)

Recall = metrics.recall_score(y_test, preds)
print('Recall:', Recall*100)

F1_score = metrics.f1_score(y_test, preds)
print('F1 Score:', F1_score*100)
# Out:
# Accuracy: 85.24590163934425
# Precision: 83.78378378378379
# Recall: 91.17647058823529
# F1 Score: 87.32394366197182

# %%
roc_auc = roc_auc_score(y_test,preds)
print('ROC AUC score: %.3f' % roc_auc)
print('Mean ROC AUC: %.5f' % roc_auc.mean())

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,preds)

auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--' ,'No Skill')
plt.plot(fpr_keras, tpr_keras, label = 'area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc = 'best')
plt.show()
# Out:
# ROC AUC score: 0.845
# Mean ROC AUC: 0.84477

# %%
target_names=['Normal', 'Abnormal']
print(classification_report(preds, y_test,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.78      0.88      0.82        24
#     Abnormal       0.91      0.84      0.87        37
#
#     accuracy                           0.85        61
#    macro avg       0.84      0.86      0.85        61
# weighted avg       0.86      0.85      0.85        61

# %%
from sklearn.tree import DecisionTreeClassifier

# create Gaussian Naive Bayes model object and train it with the data
dt_model = DecisionTreeClassifier(random_state=42)

dt_model.fit(X_train, y_train.to_numpy())
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Predict on test set using fitted model
preds = dt_model.predict(X_test)

# %%
#testing accuracy
accuracy_score(y_test, preds)
# Out:
# 0.7868852459016393

# %%
#print confusion matrix
classes = ["Normal","AbNormal"]
cm = confusion_matrix(y_test,preds)

print('Confusion Matrix')
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=classes)
fig, ax = plt.subplots(figsize=(5,5))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Confusion Matrix
# [[22  5]
#  [ 8 26]]

# %%
Accuracy = metrics.accuracy_score(y_test, preds)
print('Accuracy:', Accuracy*100)

Precision = metrics.precision_score(y_test, preds)
print('Precision:', Precision*100)

Recall = metrics.recall_score(y_test, preds)
print('Recall:', Recall*100)

F1_score = metrics.f1_score(y_test, preds)
print('F1 Score:', F1_score*100)
# Out:
# Accuracy: 78.68852459016394
# Precision: 83.87096774193549
# Recall: 76.47058823529412
# F1 Score: 80.0

# %%
roc_auc = roc_auc_score(y_test,preds)
print('ROC AUC score: %.3f' % roc_auc)
print('Mean ROC AUC: %.5f' % roc_auc.mean())

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,preds)

auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--' ,'No Skill')
plt.plot(fpr_keras, tpr_keras, label = 'area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc = 'best')
plt.show()
# Out:
# ROC AUC score: 0.790
# Mean ROC AUC: 0.78976

# %%
target_names=['Normal', 'Abnormal']
print(classification_report(preds, y_test,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.81      0.73      0.77        30
#     Abnormal       0.76      0.84      0.80        31
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.79      0.79        61
# weighted avg       0.79      0.79      0.79        61

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_train, y_train.to_numpy())
# Out:
# LogisticRegression(random_state=42)

# %%
preds = logistic_model.predict(X_test)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.8360655737704918

# %%
#print confusion matrix
classes = ["Normal","AbNormal"]
cm = confusion_matrix(y_test,preds)

print('Confusion Matrix')
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=classes)
fig, ax = plt.subplots(figsize=(5,5))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Confusion Matrix
# [[20  7]
#  [ 3 31]]

# %%
Accuracy = metrics.accuracy_score(y_test, preds)
print('Accuracy:', Accuracy*100)

Precision = metrics.precision_score(y_test, preds)
print('Precision:', Precision*100)

Recall = metrics.recall_score(y_test, preds)
print('Recall:', Recall*100)

F1_score = metrics.f1_score(y_test, preds)
print('F1 Score:', F1_score*100)
# Out:
# Accuracy: 83.60655737704919
# Precision: 81.57894736842105
# Recall: 91.17647058823529
# F1 Score: 86.11111111111111

# %%
roc_auc = roc_auc_score(y_test,preds)
print('ROC AUC score: %.3f' % roc_auc)
print('Mean ROC AUC: %.5f' % roc_auc.mean())

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,preds)

auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--' ,'No Skill')
plt.plot(fpr_keras, tpr_keras, label = 'area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc = 'best')
plt.show()
# Out:
# ROC AUC score: 0.826
# Mean ROC AUC: 0.82625

# %%
target_names=['Normal', 'Abnormal']
print(classification_report(preds, y_test,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.74      0.87      0.80        23
#     Abnormal       0.91      0.82      0.86        38
#
#     accuracy                           0.84        61
#    macro avg       0.83      0.84      0.83        61
# weighted avg       0.85      0.84      0.84        61

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)

rf_model.fit(X_train, y_train.to_numpy())
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predict on test set using fitted model
preds = rf_model.predict(X_test)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.8524590163934426

# %%
#print confusion matrix
classes = ["Normal","AbNormal"]
cm = confusion_matrix(y_test,preds)

print('Confusion Matrix')
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=classes)
fig, ax = plt.subplots(figsize=(5,5))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Confusion Matrix
# [[22  5]
#  [ 4 30]]

# %%
Accuracy = metrics.accuracy_score(y_test, preds)
print('Accuracy:', Accuracy*100)

Precision = metrics.precision_score(y_test, preds)
print('Precision:', Precision*100)

Recall = metrics.recall_score(y_test, preds)
print('Recall:', Recall*100)

F1_score = metrics.f1_score(y_test, preds)
print('F1 Score:', F1_score*100)
# Out:
# Accuracy: 85.24590163934425
# Precision: 85.71428571428571
# Recall: 88.23529411764706
# F1 Score: 86.95652173913044

# %%
roc_auc = roc_auc_score(y_test,preds)
print('ROC AUC score: %.3f' % roc_auc)
print('Mean ROC AUC: %.5f' % roc_auc.mean())

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,preds)

auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--' ,'No Skill')
plt.plot(fpr_keras, tpr_keras, label = 'area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc = 'best')
plt.show()
# Out:
# ROC AUC score: 0.849
# Mean ROC AUC: 0.84858

# %%
target_names=['Normal', 'Abnormal']
print(classification_report(preds, y_test,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.81      0.85      0.83        26
#     Abnormal       0.88      0.86      0.87        35
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %% [markdown]
# XGBoost

# %%
# !Pip install XGBoost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: XGBoost in c:\users\23adsb66\appdata\roaming\python\python312\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from XGBoost) (1.26.4)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from XGBoost) (1.13.1)

# %%
from xGBoost import XGBClassifier

# create XGBClassifier object and train it with the data
xgb_model = XGBClassifier(random_state=42)

xgb_model.fit(X_train, y_train.ravel())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from xGBoost import XGBClassifier
#       3 # create XGBClassifier object and train it with the data
#       4 xgb_model = XGBClassifier(random_state=42)
#
# ModuleNotFoundError: No module named 'xGBoost'

# %%
from xGBoost import XGBClassifier

# create XGBClassifier object and train it with the data
xgb_model = XGBClassifier(random_state=42)

xgb_model.fit(X_train, y_train.ravel())

# %%
# Predict on test set using fitted model
preds = xgb_model.predict(X_test)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.8524590163934426

# %%
#print confusion matrix
classes = ["Normal","AbNormal"]
cm = confusion_matrix(y_test,preds)

print('Confusion Matrix')
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=classes)
fig, ax = plt.subplots(figsize=(5,5))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Confusion Matrix
# [[22  5]
#  [ 4 30]]

# %%
Accuracy = metrics.accuracy_score(y_test, preds)
print('Accuracy:', Accuracy*100)

Precision = metrics.precision_score(y_test, preds)
print('Precision:', Precision*100)

Recall = metrics.recall_score(y_test, preds)
print('Recall:', Recall*100)

F1_score = metrics.f1_score(y_test, preds)
print('F1 Score:', F1_score*100)
# Out:
# Accuracy: 85.24590163934425
# Precision: 85.71428571428571
# Recall: 88.23529411764706
# F1 Score: 86.95652173913044

# %%
roc_auc = roc_auc_score(y_test,preds)
print('ROC AUC score: %.3f' % roc_auc)
print('Mean ROC AUC: %.5f' % roc_auc.mean())

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,preds)

auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--' ,'No Skill')
plt.plot(fpr_keras, tpr_keras, label = 'area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc = 'best')
plt.show()
# Out:
# ROC AUC score: 0.849
# Mean ROC AUC: 0.84858

# %%
target_names=['Normal', 'Abnormal']
print(classification_report(preds, y_test,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.81      0.85      0.83        26
#     Abnormal       0.88      0.86      0.87        35
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# create SVM model object and train it with the data
svm_model = SVC(random_state=42)

svm_model.fit(X_train, y_train.to_numpy())
# Out:
# SVC(random_state=42)

# %%
# Predict on test set using fitted model
preds = svm_model.predict(X_test)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.8360655737704918

# %%
#print confusion matrix
classes = ["Normal","AbNormal"]
cm = confusion_matrix(y_test,preds)

print('Confusion Matrix')
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=classes)
fig, ax = plt.subplots(figsize=(5,5))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Confusion Matrix
# [[19  8]
#  [ 2 32]]

# %%
Accuracy = metrics.accuracy_score(y_test, preds)
print('Accuracy:', Accuracy*100)

Precision = metrics.precision_score(y_test, preds)
print('Precision:', Precision*100)

Recall = metrics.recall_score(y_test, preds)
print('Recall:', Recall*100)

F1_score = metrics.f1_score(y_test, preds)
print('F1 Score:', F1_score*100)
# Out:
# Accuracy: 83.60655737704919
# Precision: 80.0
# Recall: 94.11764705882352
# F1 Score: 86.48648648648648

# %%
roc_auc = roc_auc_score(y_test,preds)
print('ROC AUC score: %.3f' % roc_auc)
print('Mean ROC AUC: %.5f' % roc_auc.mean())

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,preds)

auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--' ,'No Skill')
plt.plot(fpr_keras, tpr_keras, label = 'area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc = 'best')
plt.show()
# Out:
# ROC AUC score: 0.822
# Mean ROC AUC: 0.82244

# %%
target_names=['Normal', 'Abnormal']
print(classification_report(preds, y_test,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.90      0.79        21
#     Abnormal       0.94      0.80      0.86        40
#
#     accuracy                           0.84        61
#    macro avg       0.82      0.85      0.83        61
# weighted avg       0.86      0.84      0.84        61
